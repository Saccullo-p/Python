# %% [markdown]
# Installazione di Redis

# %%
pip install redis

# %%
import redis

# %% [markdown]
# Connessione al server Redis

# %%
r = redis.Redis(host='localhost', port=6379, db=0)

# %% [markdown]
# Inserimento dati

# %%
r.set('mykey', 'myvalue')

# %% [markdown]
# Recupero dati

# %%
value = r.get('mykey')
